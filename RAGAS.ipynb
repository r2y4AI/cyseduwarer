# %%
# !pip install dataset
# !pip install ragas
# !pip install langchain
# !pip install langchain_community
# !pip install langchain-ollama

from datasets import Dataset
import os
from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness, answer_relevancy, context_recall, context_precision
from langchain_ollama import ChatOllama
from langchain_ollama import OllamaEmbeddings

# %%
data_samples = {
    'question': [
        'When was the first super bowl?',
        'Who won the most super bowls?'
    ],
    'answer': [
        'The first superbowl was held on Jan 15, 1967',
        'The most super bowls have been won by The New England Patriots'
    ],
    'contexts': [
        [
            'The First AFL–NFL World Championship Game was an American football game played on January 15, 1967, at the Los Angeles Memorial Coliseum in Los Angeles,'
        ],
        [
            'The Green Bay Packers...Green Bay, Wisconsin.',
            'The Packers compete...Football Conference'
        ]
    ],
    'ground_truth': [
        'The first superbowl was held on January 15, 1967',
        'The New England Patriots have won the Super Bowl a record six times'
    ]
}

# %%
dataset = Dataset.from_dict(data_samples)

dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'contexts', 'ground_truth'],
#     num_rows: 2
# })

# %%
# !sudo apt update && sudo apt install pciutils lshw

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()

time.sleep(5)

# %%
# !ollama pull nomic-embed-text
# !ollama pull llama3.1:8b
# !ollama pull mistral:7b
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# mistral:7b                 6577803aa9a0    4.4 GB    Less than a second ago
# llama3.1:8b                46e0c10c039e    4.9 GB    About a minute ago
# nomic-embed-text:latest    0a109f422b47    274 MB    2 minutes ago

# %% [markdown]
# **Llama LLM:**

# %%
langchain_llm = ChatOllama(model="llama3.1:8b")
langchain_embeddings = OllamaEmbeddings(model="nomic-embed-text")


result = evaluate(dataset,
                  metrics=[
                      faithfulness,
                      answer_correctness,
                      answer_relevancy,
                      context_recall,
                      context_precision], llm=langchain_llm,embeddings=langchain_embeddings)

result
# Out:
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[4]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[6]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[7]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[9]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[3]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[8]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[0]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[5]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[1]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[2]: ConnectError(All connection attempts failed)
# {'faithfulness': nan, 'answer_correctness': nan, 'answer_relevancy': nan, 'context_recall': nan, 'context_precision': nan}

# %% [markdown]
# **Mistral LLM:**

# %%
langchain_llm = ChatOllama(model="mistral:7b")
langchain_embeddings = OllamaEmbeddings(model="nomic-embed-text")


result = evaluate(dataset,
                  metrics=[
                      faithfulness,
                      answer_correctness,
                      answer_relevancy,
                      context_recall,
                      context_precision], llm=langchain_llm,embeddings=langchain_embeddings)

result
# Out:
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[7]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[1]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[2]: ConnectError(All connection attempts failed)
# ERROR:ragas.executor:Exception raised in Job[0]: ConnectError(All connection attempts failed)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-699895270.py in <cell line: 0>()
#       3
#       4
# ----> 5 result = evaluate(dataset,
#       6                   metrics=[
#       7                       faithfulness,
#
# /usr/local/lib/python3.12/dist-packages/ragas/_analytics.py in wrapper(*args, **kwargs)
#     275     def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     276         track(IsCompleteEvent(event_type=func.__name__, is_completed=False))
# --> 277         result = func(*args, **kwargs)
#     278         track(IsCompleteEvent(event_type=func.__name__, is_completed=True))
#     279
#
# /usr/local/lib/python3.12/dist-packages/ragas/evaluation.py in evaluate(dataset, metrics, llm, embeddings, experiment_name, callbacks, run_config, token_usage_parser, raise_exceptions, column_map, show_progress, batch_size, _run_id, _pbar, return_executor, allow_nest_asyncio)
#     459         from ragas.async_utils import run
#     460
# --> 461         return run(_async_wrapper())
#
# /usr/local/lib/python3.12/dist-packages/ragas/async_utils.py in run(async_func, allow_nest_asyncio)
#     154         )
#     155
# --> 156     return asyncio.run(coro)
#     157
#     158
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in _run_once(self)
#     113                 scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114             else None)
# --> 115         event_list = self._selector.select(timeout)
#     116         self._process_events(event_list)
#     117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
